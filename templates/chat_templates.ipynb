# %% [markdown]
# # LLM Templates
#
# This notebook contains templatess for modular tasks encountered in LLM development. All code blocks should be able to be ran standalone meaning redundant imports
# will occur. This is so each block can be copied and pasted for modularity.
#
#
# TODO
# - OpenAI templates
#     - single text completion API
#     - multi message chat API
# - Claude templates
#     - single text completion API
#     - multi message chat API

# %% [markdown]
# ## OpenAI

# %% [markdown]
# ## Anthropic
